# %% [markdown]
# ### Cricket data collection notebook <br>
#
# --> No weather data included. <br>

# %%
#import dependencies 
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
# from tabulate import tabulate

# %%
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
browser = init_browser()

# %%
url = "http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2016;type=year"
browser.visit(url)

# %%
html = browser.html
soup = bs(html, "html.parser")

# %%
table = soup.table #or table = soup.find(table)
print(table)
# Out:
# <table class="engineTable">
# <caption>Match results</caption>
# <thead>
# <tr class="head">
# <th class="left" nowrap="nowrap" title="team">Team 1</th>
# <th class="left" nowrap="nowrap" title="team">Team 2</th>
# <th class="left" nowrap="nowrap" title="winner/result">Winner</th>
# <th class="left" nowrap="nowrap" title="result margin">Margin</th>
# <th class="left" nowrap="nowrap" title="ground played on">Ground</th>
# <th nowrap="nowrap" title="match date span">Match Date</th>
# <th nowrap="nowrap" title="match scorecard">Scorecard</th>
# </tr>
# </thead>
# <tbody>
# <tr class="data1" data-days="736330">
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/team/5.html">New Zealand</a></td>
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/team/8.html">Sri Lanka</a></td>
# <td class="left" nowrap="nowrap">no result</td>
# <td class="left" nowrap="nowrap"></td>
# ...

# %%
table_rows = soup.find_all('tr')
print(table_rows)
# Out:
# [<tr class="head">
# <th class="left" nowrap="nowrap" title="team">Team 1</th>
# <th class="left" nowrap="nowrap" title="team">Team 2</th>
# <th class="left" nowrap="nowrap" title="winner/result">Winner</th>
# <th class="left" nowrap="nowrap" title="result margin">Margin</th>
# <th class="left" nowrap="nowrap" title="ground played on">Ground</th>
# <th nowrap="nowrap" title="match date span">Match Date</th>
# <th nowrap="nowrap" title="match scorecard">Scorecard</th>
# </tr>, <tr class="data1" data-days="736330">
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/team/5.html">New Zealand</a></td>
# <td class="left" nowrap="nowrap"><a class="data-link" href="/ci/content/team/8.html">Sri Lanka</a></td>
# <td class="left" nowrap="nowrap">no result</td>
# <td class="left" nowrap="nowrap"></td>
# <td class="left"><a class="data-link" href="/ci/content/ground/424917.html">Nelson</a></td>
# <td nowrap="nowrap">Jan 2, 2016</td>
# ...

# %%
for tr in table_rows:
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['New Zealand', 'Sri Lanka', 'no result', '', 'Nelson', 'Jan 2, 2016', 'ODI # 3718']
# ['Afghanistan', 'Zimbabwe', 'Zimbabwe', '117 runs', 'Sharjah', 'Jan 2, 2016', 'ODI # 3719']
# ['Afghanistan', 'Zimbabwe', 'Zimbabwe', '65 runs', 'Sharjah', 'Jan 4, 2016', 'ODI # 3720']
# ['New Zealand', 'Sri Lanka', 'New Zealand', '36 runs', 'Mount Maunganui', 'Jan 5, 2016', 'ODI # 3721']
# ['Afghanistan', 'Zimbabwe', 'Afghanistan', '2 wickets', 'Sharjah', 'Jan 6, 2016', 'ODI # 3722']
# ['Australia', 'India', 'Australia', '5 wickets', 'Perth', 'Jan 12, 2016', 'ODI # 3723']
# ['Australia', 'India', 'Australia', '7 wickets', 'Brisbane', 'Jan 15, 2016', 'ODI # 3724']
# ['Australia', 'India', 'Australia', '3 wickets', 'Melbourne', 'Jan 17, 2016', 'ODI # 3725']
# ['Australia', 'India', 'Australia', '25 runs', 'Canberra', 'Jan 20, 2016', 'ODI # 3726']
# ['Australia', 'India', 'India', '6 wickets', 'Sydney', 'Jan 23, 2016', 'ODI # 3727']
# ...

# %% [markdown]
# ### ODI 2016

# %%
import pandas as pd

# %%
data_list = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2016;type=year', header = 0)
for df in dfs:
    print(data_list)
# Out:
# [          Team 1        Team 2        Winner      Margin           Ground  \
# 0    New Zealand     Sri Lanka     no result         NaN           Nelson
# 1    Afghanistan      Zimbabwe      Zimbabwe    117 runs          Sharjah
# 2    Afghanistan      Zimbabwe      Zimbabwe     65 runs          Sharjah
# 3    New Zealand     Sri Lanka   New Zealand     36 runs  Mount Maunganui
# 4    Afghanistan      Zimbabwe   Afghanistan   2 wickets          Sharjah
# 5      Australia         India     Australia   5 wickets            Perth
# 6      Australia         India     Australia   7 wickets         Brisbane
# 7      Australia         India     Australia   3 wickets        Melbourne
# 8      Australia         India     Australia     25 runs         Canberra
# 9      Australia         India         India   6 wickets           Sydney
# 10   New Zealand      Pakistan   New Zealand     70 runs       Wellington
# 11     Hong Kong      Scotland     Hong Kong    109 runs         Mong Kok
# ...

# %%
type(data_list)
# Out:
# list

# %%
df = data_list[0]
df.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']
df.head()
# Out:
#          Team1      Team2       Winner     Margin           Ground  \
# 0  New Zealand  Sri Lanka    no result        NaN           Nelson
# 1  Afghanistan   Zimbabwe     Zimbabwe   117 runs          Sharjah
# 2  Afghanistan   Zimbabwe     Zimbabwe    65 runs          Sharjah
# 3  New Zealand  Sri Lanka  New Zealand    36 runs  Mount Maunganui
# 4  Afghanistan   Zimbabwe  Afghanistan  2 wickets          Sharjah
#
#     Match_Date   Scorecard
# 0  Jan 2, 2016  ODI # 3718
# 1  Jan 2, 2016  ODI # 3719
# 2  Jan 4, 2016  ODI # 3720
# 3  Jan 5, 2016  ODI # 3721
# 4  Jan 6, 2016  ODI # 3722

# %%
df.shape
# Out:
# (99, 7)

# %% [markdown]
# ### T20 Data 2016

# %%
data_list_2016_t20 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2016;type=year', header = 0)
for data in data_list_2016_t20:
    print(data_list_2016_t20)
# Out:
# [          Team 1       Team 2        Winner      Margin           Ground  \
# 0    New Zealand    Sri Lanka   New Zealand      3 runs  Mount Maunganui
# 1    Afghanistan     Zimbabwe   Afghanistan      5 runs          Sharjah
# 2    New Zealand    Sri Lanka   New Zealand   9 wickets         Auckland
# 3    Afghanistan     Zimbabwe   Afghanistan     81 runs          Sharjah
# 4    New Zealand     Pakistan      Pakistan     16 runs         Auckland
# 5     Bangladesh     Zimbabwe    Bangladesh   4 wickets           Khulna
# 6    New Zealand     Pakistan   New Zealand  10 wickets         Hamilton
# 7     Bangladesh     Zimbabwe    Bangladesh     42 runs           Khulna
# 8     Bangladesh     Zimbabwe      Zimbabwe     31 runs           Khulna
# 9    New Zealand     Pakistan   New Zealand     95 runs       Wellington
# 10    Bangladesh     Zimbabwe      Zimbabwe     18 runs           Khulna
# 11     Australia        India         India     37 runs         Adelaide
# ...

# %%
df_t20 = data_list_2016_t20[0]
df_t20.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']
df_t20.head()
# Out:
#          Team1      Team2       Winner     Margin           Ground  \
# 0  New Zealand  Sri Lanka  New Zealand     3 runs  Mount Maunganui
# 1  Afghanistan   Zimbabwe  Afghanistan     5 runs          Sharjah
# 2  New Zealand  Sri Lanka  New Zealand  9 wickets         Auckland
# 3  Afghanistan   Zimbabwe  Afghanistan    81 runs          Sharjah
# 4  New Zealand   Pakistan     Pakistan    16 runs         Auckland
#
#      Match_Date   Scorecard
# 0   Jan 7, 2016  T20I # 474
# 1   Jan 8, 2016  T20I # 475
# 2  Jan 10, 2016  T20I # 476
# 3  Jan 10, 2016  T20I # 477
# 4  Jan 15, 2016  T20I # 478

# %%
df_t20.shape
# Out:
# (100, 7)

# %% [markdown]
# ### Test 2016

# %%
data_list_2016_test = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2016;type=year', header = 0)
for data in data_list_2016_test:
    print(data_list_2016_test)
# Out:
# [          Team 1        Team 2        Winner           Margin  \
# 0   South Africa       England         drawn              NaN
# 1      Australia   West Indies         drawn              NaN
# 2   South Africa       England       England        7 wickets
# 3   South Africa       England  South Africa         280 runs
# 4    New Zealand     Australia     Australia   inns & 52 runs
# 5    New Zealand     Australia     Australia        7 wickets
# 6        England     Sri Lanka       England   inns & 88 runs
# 7        England     Sri Lanka       England        9 wickets
# 8        England     Sri Lanka         drawn              NaN
# 9        England      Pakistan      Pakistan          75 runs
# 10   West Indies         India         India   inns & 92 runs
# 11       England      Pakistan       England         330 runs
# 12     Sri Lanka     Australia     Sri Lanka         106 runs
# 13      Zimbabwe   New Zealand   New Zealand  inns & 117 runs
# ...

# %%
df_test2016 = data_list_2016_test[0]
df_test2016.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']
df_test2016.head()
# Out:
#           Team1        Team2        Winner          Margin        Ground  \
# 0  South Africa      England         drawn             NaN     Cape Town
# 1     Australia  West Indies         drawn             NaN        Sydney
# 2  South Africa      England       England       7 wickets  Johannesburg
# 3  South Africa      England  South Africa        280 runs     Centurion
# 4   New Zealand    Australia     Australia  inns & 52 runs    Wellington
#
#         Match_Date    Scorecard
# 0    Jan 2-6, 2016  Test # 2197
# 1    Jan 3-7, 2016  Test # 2198
# 2  Jan 14-16, 2016  Test # 2199
# 3  Jan 22-26, 2016  Test # 2200
# 4  Feb 12-15, 2016  Test # 2201

# %%
df_test2016.shape
# Out:
# (47, 7)

# %% [markdown]
# # Cricket 2017

# %% [markdown]
# ### ODI 2017

# %%
data_list_odi17 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2017;type=year', header = 0)
for data in data_list_odi17:
    print(data_list_odi17)
    
df_odi17 = data_list_odi17[0]
df_odi17.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

df_odi17.head()
# Out:
# [           Team 1        Team 2        Winner      Margin          Ground  \
# 0       Australia      Pakistan     Australia     92 runs        Brisbane
# 1       Australia      Pakistan      Pakistan   6 wickets       Melbourne
# 2           India       England         India   3 wickets            Pune
# 3       Australia      Pakistan     Australia   7 wickets           Perth
# 4           India       England         India     15 runs         Cuttack
# 5       Australia      Pakistan     Australia     86 runs          Sydney
# 6       Hong Kong      Scotland     Hong Kong   7 wickets       Abu Dhabi
# 7           India       England       England      5 runs         Kolkata
# 8          U.A.E.      Scotland        U.A.E.   4 wickets     Dubai (DSC)
# 9       Australia      Pakistan     Australia     57 runs        Adelaide
# 10         U.A.E.     Hong Kong        U.A.E.   6 wickets     Dubai (DSC)
# 11   South Africa     Sri Lanka  South Africa   8 wickets  Port Elizabeth
# ...

# %%
df_odi17.shape
# Out:
# (129, 7)

# %% [markdown]
# ### T20 2017

# %%
data_list_t2017 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2017;type=year', header = 0)
# for data in data_list_odi17:
#     print(data_list_odi17)
    
df_t2017 = data_list_t2017[0]
df_t2017.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

df_t2017.head()
# Out:
#          Team1       Team2       Winner     Margin           Ground  \
# 0  New Zealand  Bangladesh  New Zealand  6 wickets           Napier
# 1  New Zealand  Bangladesh  New Zealand    47 runs  Mount Maunganui
# 2  New Zealand  Bangladesh  New Zealand    27 runs  Mount Maunganui
# 3    Hong Kong    Scotland     Scotland    24 runs        Abu Dhabi
# 4  Afghanistan     Ireland  Afghanistan  5 wickets        Abu Dhabi
#
#      Match_Date   Scorecard
# 0   Jan 3, 2017  T20I # 574
# 1   Jan 6, 2017  T20I # 575
# 2   Jan 8, 2017  T20I # 576
# 3  Jan 14, 2017  T20I # 577
# 4  Jan 14, 2017  T20I # 578

# %%
df_t2017.shape
# Out:
# (63, 7)

# %% [markdown]
# ### Test 2017

# %%
data_list_test17 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2017;type=year', header = 0)
    
df_test17 = data_list_test17[0]
df_test17.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

df_test17.head()
# Out:
#           Team1       Team2        Winner           Margin        Ground  \
# 0  South Africa   Sri Lanka  South Africa         282 runs     Cape Town
# 1     Australia    Pakistan     Australia         220 runs        Sydney
# 2   New Zealand  Bangladesh   New Zealand        7 wickets    Wellington
# 3  South Africa   Sri Lanka  South Africa  inns & 118 runs  Johannesburg
# 4   New Zealand  Bangladesh   New Zealand        9 wickets  Christchurch
#
#         Match_Date    Scorecard
# 0    Jan 2-5, 2017  Test # 2244
# 1    Jan 3-7, 2017  Test # 2245
# 2  Jan 12-16, 2017  Test # 2246
# 3  Jan 12-14, 2017  Test # 2247
# 4  Jan 20-23, 2017  Test # 2248

# %%
df_test17.shape
# Out:
# (47, 7)

# %% [markdown]
# # Cricket 2018

# %% [markdown]
# ### ODI 2018

# %%
data_list_odi18 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2018;type=year', header = 0)
    
df_odi18 = data_list_odi18[0]
df_odi18.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

df_odi18.head()
# Out:
#          Team1     Team2       Winner     Margin      Ground    Match_Date  \
# 0  New Zealand  Pakistan  New Zealand    61 runs  Wellington   Jan 6, 2018
# 1  New Zealand  Pakistan  New Zealand  8 wickets      Nelson   Jan 9, 2018
# 2       U.A.E.   Ireland      Ireland  4 wickets  ICCA Dubai  Jan 11, 2018
# 3  New Zealand  Pakistan  New Zealand   183 runs     Dunedin  Jan 13, 2018
# 4       U.A.E.   Ireland      Ireland    67 runs  ICCA Dubai  Jan 13, 2018
#
#     Scorecard
# 0  ODI # 3946
# 1  ODI # 3947
# 2  ODI # 3948
# 3  ODI # 3949
# 4  ODI # 3950

# %%
df_odi18.shape
# Out:
# (128, 7)

# %% [markdown]
# ### T20 2018

# %%
data_list_t2018 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2018;type=year', header = 0)
    
df_t2018 = data_list_t2018[0]
df_t2018.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

df_t2018.head()
# Out:
#          Team1        Team2       Winner     Margin           Ground  \
# 0  New Zealand  West Indies    no result        NaN  Mount Maunganui
# 1  New Zealand  West Indies  New Zealand   119 runs  Mount Maunganui
# 2  New Zealand     Pakistan  New Zealand  7 wickets       Wellington
# 3  New Zealand     Pakistan     Pakistan    48 runs         Auckland
# 4  New Zealand     Pakistan     Pakistan    18 runs  Mount Maunganui
#
#      Match_Date   Scorecard
# 0   Jan 1, 2018  T20I # 637
# 1   Jan 3, 2018  T20I # 638
# 2  Jan 22, 2018  T20I # 639
# 3  Jan 25, 2018  T20I # 640
# 4  Jan 28, 2018  T20I # 641

# %%
df_t2018.shape
# Out:
# (81, 7)

# %% [markdown]
# ### Test 2018

# %%
data_list_test18 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2018;type=year', header = 0)
    
df_test18 = data_list_test18[0]
df_test18.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

df_test18.head()
# Out:
#           Team1      Team2        Winner           Margin        Ground  \
# 0     Australia    England     Australia  inns & 123 runs        Sydney
# 1  South Africa      India  South Africa          72 runs     Cape Town
# 2  South Africa      India  South Africa         135 runs     Centurion
# 3  South Africa      India         India          63 runs  Johannesburg
# 4    Bangladesh  Sri Lanka         drawn              NaN    Chattogram
#
#            Match_Date    Scorecard
# 0       Jan 4-8, 2018  Test # 2291
# 1       Jan 5-8, 2018  Test # 2292
# 2     Jan 13-17, 2018  Test # 2293
# 3     Jan 24-27, 2018  Test # 2294
# 4  Jan 31-Feb 4, 2018  Test # 2295

# %%
df_test18.shape
# Out:
# (48, 7)

# %% [markdown]
# ## Append df 16,17,18

# %% [markdown]
# ### ODI Data for 16,17,18

# %%
odi_df_1617 = df.append(df_odi17)
print(odi_df_1617.shape)

odi_df_161718 = odi_df_1617.append(df_odi18)
print(odi_df_161718.head())

print(odi_df_161718.shape)
# Out:
# (228, 7)
#          Team1      Team2       Winner     Margin           Ground  \
# 0  New Zealand  Sri Lanka    no result        NaN           Nelson
# 1  Afghanistan   Zimbabwe     Zimbabwe   117 runs          Sharjah
# 2  Afghanistan   Zimbabwe     Zimbabwe    65 runs          Sharjah
# 3  New Zealand  Sri Lanka  New Zealand    36 runs  Mount Maunganui
# 4  Afghanistan   Zimbabwe  Afghanistan  2 wickets          Sharjah
#
#     Match_Date   Scorecard
# 0  Jan 2, 2016  ODI # 3718
# 1  Jan 2, 2016  ODI # 3719
# 2  Jan 4, 2016  ODI # 3720
# 3  Jan 5, 2016  ODI # 3721
# 4  Jan 6, 2016  ODI # 3722
# (356, 7)

# %% [markdown]
# ### T20 Data for 16,17,18

# %%
t20_df_1617 = df_t20.append(df_t2017)
print(t20_df_1617.shape)

t20_df_161718 = t20_df_1617.append(df_t2018)
print(t20_df_161718.head())

print(t20_df_161718.shape)
# Out:
# (163, 7)
#          Team1      Team2       Winner     Margin           Ground  \
# 0  New Zealand  Sri Lanka  New Zealand     3 runs  Mount Maunganui
# 1  Afghanistan   Zimbabwe  Afghanistan     5 runs          Sharjah
# 2  New Zealand  Sri Lanka  New Zealand  9 wickets         Auckland
# 3  Afghanistan   Zimbabwe  Afghanistan    81 runs          Sharjah
# 4  New Zealand   Pakistan     Pakistan    16 runs         Auckland
#
#      Match_Date   Scorecard
# 0   Jan 7, 2016  T20I # 474
# 1   Jan 8, 2016  T20I # 475
# 2  Jan 10, 2016  T20I # 476
# 3  Jan 10, 2016  T20I # 477
# 4  Jan 15, 2016  T20I # 478
# (244, 7)

# %% [markdown]
# ### Test Data for 16,17,18

# %%
test_df_1617 = df_test2016.append(df_test17)
print(test_df_1617.shape)

test_df_161718 = test_df_1617.append(df_test18)
test_df_161718.head()

print(test_df_161718.shape)
# Out:
# (94, 7)
# (142, 7)

# %%
test_df_161718.tail(2)
# Out:
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket Data 2015

# %% [markdown]
# ### ODI 2015

# %%
data_list_odi15 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2015;type=year', header = 0)
    
df_odi15 = data_list_odi15[0]
df_odi15.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi15.shape)
df_odi15.head()
# Out:
# (146, 7)
#          Team1      Team2       Winner     Margin        Ground    Match_Date  \
# 0  Afghanistan   Scotland  Afghanistan  8 wickets    ICCA Dubai   Jan 8, 2015
# 1  Afghanistan    Ireland      Ireland  3 wickets   Dubai (DSC)  Jan 10, 2015
# 2  New Zealand  Sri Lanka  New Zealand  3 wickets  Christchurch  Jan 11, 2015
# 3      Ireland   Scotland      Ireland  3 wickets   Dubai (DSC)  Jan 12, 2015
# 4  Afghanistan   Scotland     Scotland   150 runs     Abu Dhabi  Jan 14, 2015
#
#     Scorecard
# 0  ODI # 3572
# 1  ODI # 3573
# 2  ODI # 3574
# 3  ODI # 3575
# 4  ODI # 3576

# %%
#APPEND DF 2015 ONWARDS


odi_df_from15 =  df_odi15.append(odi_df_161718)
print(odi_df_from15.shape)
odi_df_from15.tail(2)
# Out:
# (502, 7)
#           Team1        Team2       Winner     Margin  Ground    Match_Date  \
# 126  Bangladesh  West Indies  West Indies  4 wickets   Dhaka  Dec 11, 2018
# 127  Bangladesh  West Indies   Bangladesh  8 wickets  Sylhet  Dec 14, 2018
#
#       Scorecard
# 126  ODI # 4072
# 127  ODI # 4073

# %% [markdown]
# ### T20 2015

# %%
data_list_t2015 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2015;type=year', header = 0)
    
df_t2015 = data_list_t2015[0]
df_t2015.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2015.shape)
df_t2015.head()
# Out:
# (61, 7)
#           Team1        Team2        Winner     Margin        Ground  \
# 0  South Africa  West Indies   West Indies  4 wickets     Cape Town
# 1  South Africa  West Indies   West Indies  4 wickets  Johannesburg
# 2  South Africa  West Indies  South Africa    69 runs        Durban
# 3    Bangladesh     Pakistan    Bangladesh  7 wickets         Dhaka
# 4      Pakistan     Zimbabwe      Pakistan  5 wickets        Lahore
#
#      Match_Date   Scorecard
# 0   Jan 9, 2015  T20I # 413
# 1  Jan 11, 2015  T20I # 414
# 2  Jan 14, 2015  T20I # 415
# 3  Apr 24, 2015  T20I # 416
# 4  May 22, 2015  T20I # 417

# %%
# APPEND T20 FROM 2015 ONWARDS

t20_df_from2015 = df_t2015.append(t20_df_161718)
print(t20_df_from2015.shape)

t20_df_from2015.tail(2)
# Out:
# (305, 7)
#          Team1        Team2       Winner   Margin Ground    Match_Date  \
# 79  Bangladesh  West Indies   Bangladesh  36 runs  Dhaka  Dec 20, 2018
# 80  Bangladesh  West Indies  West Indies  50 runs  Dhaka  Dec 22, 2018
#
#      Scorecard
# 79  T20I # 716
# 80  T20I # 717

# %% [markdown]
# ### Test 2015

# %%
data_list_test15 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2015;type=year', header = 0)
    
df_test15 = data_list_test15[0]
df_test15.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test15.shape)
df_test15.head()
# Out:
# (43, 7)
#           Team1        Team2        Winner     Margin       Ground  \
# 0  South Africa  West Indies  South Africa  8 wickets    Cape Town
# 1   New Zealand    Sri Lanka   New Zealand   193 runs   Wellington
# 2     Australia        India         drawn        NaN       Sydney
# 3   West Indies      England         drawn        NaN  North Sound
# 4   West Indies      England       England  9 wickets  St George's
#
#         Match_Date    Scorecard
# 0    Jan 2-6, 2015  Test # 2154
# 1    Jan 3-7, 2015  Test # 2155
# 2   Jan 6-10, 2015  Test # 2156
# 3  Apr 13-17, 2015  Test # 2157
# 4  Apr 21-25, 2015  Test # 2158

# %%
# APPEND TEST DATAFRAMES

test_df_from2015 = df_test15.append(test_df_161718)
print(test_df_from2015.shape)

test_df_from2015.tail(2)
# Out:
# (185, 7)
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket 2014 <br>
#
# appended data included

# %% [markdown]
# ### ODI 2014

# %%
data_list_odi14 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2014;type=year', header = 0)
    
df_odi14 = data_list_odi14[0]
df_odi14.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi14.shape)
df_odi14.head()
# Out:
# (121, 7)
#          Team1        Team2       Winner     Margin      Ground    Match_Date  \
# 0  New Zealand  West Indies  New Zealand   159 runs  Queenstown   Jan 1, 2014
# 1  New Zealand  West Indies  New Zealand    58 runs      Nelson   Jan 4, 2014
# 2  New Zealand  West Indies  West Indies   203 runs    Hamilton   Jan 8, 2014
# 3    Australia      England    Australia  6 wickets   Melbourne  Jan 12, 2014
# 4    Australia      England    Australia   1 wicket    Brisbane  Jan 17, 2014
#
#     Scorecard
# 0  ODI # 3451
# 1  ODI # 3452
# 2  ODI # 3453
# 3  ODI # 3454
# 4  ODI # 3455

# %%
odi_df_from2014 = df_odi14.append(odi_df_from15)
print(odi_df_from2014.shape)

odi_df_from2014.tail(2)
# Out:
# (623, 7)
#           Team1        Team2       Winner     Margin  Ground    Match_Date  \
# 126  Bangladesh  West Indies  West Indies  4 wickets   Dhaka  Dec 11, 2018
# 127  Bangladesh  West Indies   Bangladesh  8 wickets  Sylhet  Dec 14, 2018
#
#       Scorecard
# 126  ODI # 4072
# 127  ODI # 4073

# %% [markdown]
# ### T20 2014

# %%
data_list_t2014 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2014;type=year', header = 0)
    
df_t2014 = data_list_t2014[0]
df_t2014.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2014.shape)
df_t2014.head()
# Out:
# (61, 7)
#          Team1        Team2       Winner     Margin      Ground    Match_Date  \
# 0  New Zealand  West Indies  New Zealand    81 runs    Auckland  Jan 11, 2014
# 1  New Zealand  West Indies  New Zealand  4 wickets  Wellington  Jan 15, 2014
# 2    Australia      England    Australia    13 runs      Hobart  Jan 29, 2014
# 3    Australia      England    Australia  8 wickets   Melbourne  Jan 31, 2014
# 4    Australia      England    Australia    84 runs      Sydney   Feb 2, 2014
#
#     Scorecard
# 0  T20I # 352
# 1  T20I # 353
# 2  T20I # 354
# 3  T20I # 355
# 4  T20I # 356

# %%
t20_df_from2014 = df_t2014.append(t20_df_from2015)
print(t20_df_from2014.shape)

t20_df_from2014.tail()
# Out:
# (366, 7)
#          Team1        Team2       Winner     Margin     Ground    Match_Date  \
# 76   Australia        India    no result        NaN  Melbourne  Nov 23, 2018
# 77   Australia        India        India  6 wickets     Sydney  Nov 25, 2018
# 78  Bangladesh  West Indies  West Indies  8 wickets     Sylhet  Dec 17, 2018
# 79  Bangladesh  West Indies   Bangladesh    36 runs      Dhaka  Dec 20, 2018
# 80  Bangladesh  West Indies  West Indies    50 runs      Dhaka  Dec 22, 2018
#
#      Scorecard
# 76  T20I # 713
# 77  T20I # 714
# 78  T20I # 715
# 79  T20I # 716
# 80  T20I # 717

# %% [markdown]
# ### Test 2014

# %%
data_list_test14 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2014;type=year', header = 0)
    
df_test14 = data_list_test14[0]
df_test14.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test14.shape)
df_test14.head(2)
# Out:
# (42, 7)
#        Team1      Team2     Winner    Margin     Ground  \
# 0   Pakistan  Sri Lanka      drawn       NaN  Abu Dhabi
# 1  Australia    England  Australia  281 runs     Sydney
#
#                    Match_Date    Scorecard
# 0  Dec 31, 2013 - Jan 4, 2014  Test # 2112
# 1               Jan 3-5, 2014  Test # 2113

# %%
test_df_from2014 = df_test14.append(test_df_from2015)
print(test_df_from2014.shape)

test_df_from2014.tail(2)
# Out:
# (227, 7)
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket 2013 <br>
# appended included

# %% [markdown]
# ### ODI 2013

# %%
data_list_odi13 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2013;type=year', header = 0)
    
df_odi13 = data_list_odi13[0]
df_odi13.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi13.shape)
df_odi13.head(2)
# Out:
# (136, 7)
#    Team1     Team2    Winner   Margin   Ground   Match_Date   Scorecard
# 0  India  Pakistan  Pakistan  85 runs  Kolkata  Jan 3, 2013  ODI # 3315
# 1  India  Pakistan     India  10 runs    Delhi  Jan 6, 2013  ODI # 3316

# %%
odi_df_from2013 = df_odi13.append(odi_df_from2014)
print(odi_df_from2013.shape)

odi_df_from2013.tail(2)
# Out:
# (759, 7)
#           Team1        Team2       Winner     Margin  Ground    Match_Date  \
# 126  Bangladesh  West Indies  West Indies  4 wickets   Dhaka  Dec 11, 2018
# 127  Bangladesh  West Indies   Bangladesh  8 wickets  Sylhet  Dec 14, 2018
#
#       Scorecard
# 126  ODI # 4072
# 127  ODI # 4073

# %% [markdown]
# ### T20 2013

# %%
data_list_t2013 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2013;type=year', header = 0)
    
df_t2013 = data_list_t2013[0]
df_t2013.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2013.shape)
df_t2013.head(2)
# Out:
# (53, 7)
#        Team1      Team2     Winner     Margin     Ground    Match_Date  \
# 0  Australia  Sri Lanka  Sri Lanka  5 wickets     Sydney  Jan 26, 2013
# 1  Australia  Sri Lanka  Sri Lanka     2 runs  Melbourne  Jan 28, 2013
#
#     Scorecard
# 0  T20I # 299
# 1  T20I # 300

# %%
t20_df_from2013 = df_t2013.append(t20_df_from2014)
print(t20_df_from2013.shape)

t20_df_from2013.tail(2)
# Out:
# (419, 7)
#          Team1        Team2       Winner   Margin Ground    Match_Date  \
# 79  Bangladesh  West Indies   Bangladesh  36 runs  Dhaka  Dec 20, 2018
# 80  Bangladesh  West Indies  West Indies  50 runs  Dhaka  Dec 22, 2018
#
#      Scorecard
# 79  T20I # 716
# 80  T20I # 717

# %% [markdown]
# ### Test 2013

# %%
data_list_test13 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2013;type=year', header = 0)
    
df_test13 = data_list_test13[0]
df_test13.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test13.shape)
df_test13.head(2)
# Out:
# (44, 7)
#           Team1        Team2        Winner          Margin     Ground  \
# 0  South Africa  New Zealand  South Africa  inns & 27 runs  Cape Town
# 1     Australia    Sri Lanka     Australia       5 wickets     Sydney
#
#       Match_Date    Scorecard
# 0  Jan 2-4, 2013  Test # 2069
# 1  Jan 3-6, 2013  Test # 2070

# %%
test_df_from2013 = df_test13.append(test_df_from2014)
print(test_df_from2014.shape)
print(test_df_from2013.shape)

test_df_from2013.tail(2)
# Out:
# (227, 7)
# (271, 7)
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket 2012 <br>
# appended included
#
# ### ODI 2012

# %%
data_list_odi12 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2012;type=year', header = 0)
    
df_odi12 = data_list_odi12[0]
df_odi12.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi12.shape)
df_odi12.head(2)
# Out:
# (90, 7)
#           Team1      Team2        Winner     Margin       Ground  \
# 0  South Africa  Sri Lanka  South Africa   258 runs        Paarl
# 1  South Africa  Sri Lanka  South Africa  5 wickets  East London
#
#      Match_Date   Scorecard
# 0  Jan 11, 2012  ODI # 3225
# 1  Jan 14, 2012  ODI # 3226

# %%
odi_df_from2012 = df_odi12.append(odi_df_from2013)
print(odi_df_from2013.shape)
print(odi_df_from2012.shape)

odi_df_from2012.tail(2)
# Out:
# (759, 7)
# (849, 7)
#           Team1        Team2       Winner     Margin  Ground    Match_Date  \
# 126  Bangladesh  West Indies  West Indies  4 wickets   Dhaka  Dec 11, 2018
# 127  Bangladesh  West Indies   Bangladesh  8 wickets  Sylhet  Dec 14, 2018
#
#       Scorecard
# 126  ODI # 4072
# 127  ODI # 4073

# %% [markdown]
# ### T20 2012

# %%
data_list_t2012 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2012;type=year', header = 0)
    
df_t2012 = data_list_t2012[0]
df_t2012.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2012.shape)
df_t2012.head(2)
# Out:
# (82, 7)
#        Team1  Team2     Winner     Margin     Ground   Match_Date   Scorecard
# 0  Australia  India  Australia    31 runs     Sydney  Feb 1, 2012  T20I # 217
# 1  Australia  India      India  8 wickets  Melbourne  Feb 3, 2012  T20I # 218

# %%
t20_df_from2012 = df_t2012.append(t20_df_from2013)
print(t20_df_from2013.shape)
print(t20_df_from2012.shape)

t20_df_from2012.tail(2)
# Out:
# (419, 7)
# (501, 7)
#          Team1        Team2       Winner   Margin Ground    Match_Date  \
# 79  Bangladesh  West Indies   Bangladesh  36 runs  Dhaka  Dec 20, 2018
# 80  Bangladesh  West Indies  West Indies  50 runs  Dhaka  Dec 22, 2018
#
#      Scorecard
# 79  T20I # 716
# 80  T20I # 717

# %% [markdown]
# ### Test 2012

# %%
data_list_test12 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2012;type=year', header = 0)
    
df_test12 = data_list_test12[0]
df_test12.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test12.shape)
df_test12.head(2)
# Out:
# (42, 7)
#           Team1      Team2        Winner          Margin     Ground  \
# 0     Australia      India     Australia  inns & 68 runs     Sydney
# 1  South Africa  Sri Lanka  South Africa      10 wickets  Cape Town
#
#       Match_Date    Scorecard
# 0  Jan 3-6, 2012  Test # 2027
# 1  Jan 3-6, 2012  Test # 2028

# %%
test_df_from2012 = df_test12.append(test_df_from2013)
print(test_df_from2013.shape)
print(test_df_from2012.shape)

test_df_from2012.tail(2)
# Out:
# (271, 7)
# (313, 7)
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket 2011 <br>
# appended included
#
# ### ODI 2011

# %%
data_list_odi11 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2011;type=year', header = 0)
    
df_odi11 = data_list_odi11[0]
df_odi11.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi11.shape)
df_odi11.head(2)
# Out:
# (146, 7)
#           Team1  Team2        Winner    Margin        Ground    Match_Date  \
# 0  South Africa  India  South Africa  135 runs        Durban  Jan 12, 2011
# 1  South Africa  India         India     1 run  Johannesburg  Jan 15, 2011
#
#     Scorecard
# 0  ODI # 3079
# 1  ODI # 3080

# %%
odi_df_from2011 = df_odi11.append(odi_df_from2012)
print(odi_df_from2012.shape)
print(odi_df_from2011.shape)

odi_df_from2011.tail(2)
# Out:
# (849, 7)
# (995, 7)
#           Team1        Team2       Winner     Margin  Ground    Match_Date  \
# 126  Bangladesh  West Indies  West Indies  4 wickets   Dhaka  Dec 11, 2018
# 127  Bangladesh  West Indies   Bangladesh  8 wickets  Sylhet  Dec 14, 2018
#
#       Scorecard
# 126  ODI # 4072
# 127  ODI # 4073

# %% [markdown]
# ### T20 2011

# %%
data_list_t2011 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2011;type=year', header = 0)
    
df_t2011 = data_list_t2011[0]
df_t2011.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2011.shape)
df_t2011.head(2)
# Out:
# (21, 7)
#           Team1    Team2   Winner    Margin    Ground    Match_Date  \
# 0  South Africa    India    India   21 runs    Durban   Jan 9, 2011
# 1     Australia  England  England  1 wicket  Adelaide  Jan 12, 2011
#
#     Scorecard
# 0  T20I # 196
# 1  T20I # 197

# %%
t20_df_from2011 = df_t2011.append(t20_df_from2012)
print(t20_df_from2012.shape)
print(t20_df_from2011.shape)

t20_df_from2011.tail(2)
# Out:
# (501, 7)
# (522, 7)
#          Team1        Team2       Winner   Margin Ground    Match_Date  \
# 79  Bangladesh  West Indies   Bangladesh  36 runs  Dhaka  Dec 20, 2018
# 80  Bangladesh  West Indies  West Indies  50 runs  Dhaka  Dec 22, 2018
#
#      Scorecard
# 79  T20I # 716
# 80  T20I # 717

# %% [markdown]
# ### Test 2011

# %%
data_list_test11 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2011;type=year', header = 0)
    
df_test11 = data_list_test11[0]
df_test11.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test11.shape)
df_test11.head(2)
# Out:
# (39, 7)
#           Team1    Team2   Winner          Margin     Ground     Match_Date  \
# 0  South Africa    India    drawn             NaN  Cape Town  Jan 2-6, 2011
# 1     Australia  England  England  inns & 83 runs     Sydney  Jan 3-7, 2011
#
#      Scorecard
# 0  Test # 1988
# 1  Test # 1989

# %%
test_df_from2011 = df_test11.append(test_df_from2012)
print(test_df_from2012.shape)
print(test_df_from2011.shape)

test_df_from2011.tail(2)
# Out:
# (313, 7)
# (352, 7)
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket 2010 <br>
# appended included
#
# ### ODI 2010

# %%
data_list_odi10 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2010;type=year', header = 0)
    
df_odi10 = data_list_odi10[0]
df_odi10.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi10.shape)
df_odi10.head(2)
# Out:
# (142, 7)
#         Team1      Team2     Winner     Margin Ground   Match_Date   Scorecard
# 0  Bangladesh  Sri Lanka  Sri Lanka  7 wickets  Dhaka  Jan 4, 2010  ODI # 2937
# 1       India  Sri Lanka  Sri Lanka  5 wickets  Dhaka  Jan 5, 2010  ODI # 2938

# %%
odi_df_from2010 = df_odi10.append(odi_df_from2011)
print(odi_df_from2011.shape)
print(odi_df_from2010.shape)

odi_df_from2010.tail(2)
# Out:
# (995, 7)
# (1137, 7)
#           Team1        Team2       Winner     Margin  Ground    Match_Date  \
# 126  Bangladesh  West Indies  West Indies  4 wickets   Dhaka  Dec 11, 2018
# 127  Bangladesh  West Indies   Bangladesh  8 wickets  Sylhet  Dec 14, 2018
#
#       Scorecard
# 126  ODI # 4072
# 127  ODI # 4073

# %% [markdown]
# ### T20 2010

# %%
data_list_t2010 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2010;type=year', header = 0)
    
df_t2010 = data_list_t2010[0]
df_t2010.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2010.shape)
df_t2010.head(2)
# Out:
# (68, 7)
#          Team1     Team2   Winner      Margin         Ground   Match_Date  \
# 0  Afghanistan   Ireland  Ireland   5 wickets  Colombo (PSS)  Feb 1, 2010
# 1        Kenya  Scotland    Kenya  10 wickets  Nairobi (Gym)  Feb 1, 2010
#
#     Scorecard
# 0  T20I # 128
# 1  T20I # 129

# %%
t20_df_from2010 = df_t2010.append(t20_df_from2011)
print(t20_df_from2011.shape)
print(t20_df_from2010.shape)

t20_df_from2010.tail(2)
# Out:
# (522, 7)
# (590, 7)
#          Team1        Team2       Winner   Margin Ground    Match_Date  \
# 79  Bangladesh  West Indies   Bangladesh  36 runs  Dhaka  Dec 20, 2018
# 80  Bangladesh  West Indies  West Indies  50 runs  Dhaka  Dec 22, 2018
#
#      Scorecard
# 79  T20I # 716
# 80  T20I # 717

# %% [markdown]
# ### Test 2010

# %%
data_list_test10 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2010;type=year', header = 0)
    
df_test10 = data_list_test10[0]
df_test10.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test10.shape)
df_test10.head(2)
# Out:
# (43, 7)
#           Team1     Team2     Winner   Margin     Ground     Match_Date  \
# 0     Australia  Pakistan  Australia  36 runs     Sydney  Jan 3-6, 2010
# 1  South Africa   England      drawn      NaN  Cape Town  Jan 3-7, 2010
#
#      Scorecard
# 0  Test # 1945
# 1  Test # 1946

# %%
test_df_from2010 = df_test10.append(test_df_from2011)
print(test_df_from2011.shape)
print(test_df_from2010.shape)

test_df_from2010.tail(2)
# Out:
# (352, 7)
# (395, 7)
#            Team1     Team2        Winner     Margin     Ground  \
# 46     Australia     India         India   137 runs  Melbourne
# 47  South Africa  Pakistan  South Africa  6 wickets  Centurion
#
#          Match_Date    Scorecard
# 46  Dec 26-30, 2018  Test # 2337
# 47  Dec 26-28, 2018  Test # 2338

# %% [markdown]
# ## Cricket 2019 <br>
# appended included
#
# ### ODI 2019

# %%
data_list_odi19 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2019;type=year', header = 0)
    
df_odi19 = data_list_odi19[0]
df_odi19.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi19.shape)
df_odi19.tail(2)
# Out:
# (119, 7)
#        Team1        Team2   Winner     Margin      Ground    Match_Date  \
# 117  England    Australia  England  8 wickets  Birmingham  Jul 11, 2019
# 118  England  New Zealand     tied        NaN      Lord's  Jul 14, 2019
#
#       Scorecard
# 117  ODI # 4191
# 118  ODI # 4192

# %%
odi_decade1 = odi_df_from2010.append(df_odi19)
print(odi_df_from2010.shape)
print(odi_decade1.shape)

odi_decade1.tail(2)
# Out:
# (1137, 7)
# (1256, 7)
#        Team1        Team2   Winner     Margin      Ground    Match_Date  \
# 117  England    Australia  England  8 wickets  Birmingham  Jul 11, 2019
# 118  England  New Zealand     tied        NaN      Lord's  Jul 14, 2019
#
#       Scorecard
# 117  ODI # 4191
# 118  ODI # 4192

# %% [markdown]
# ### T20 2019

# %%
data_list_t2019 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2019;type=year', header = 0)
    
df_t2019 = data_list_t2019[0]
df_t2019.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2019.shape)
df_t2019.tail(2)
# Out:
# (114, 7)
#         Team1     Team2    Winner     Margin        Ground    Match_Date  \
# 112  Malaysia     Nepal     Nepal     6 runs  Kuala Lumpur  Jul 14, 2019
# 113   Ireland  Zimbabwe  Zimbabwe  8 wickets        Bready  Jul 14, 2019
#
#       Scorecard
# 112  T20I # 830
# 113  T20I # 831

# %%
t20_decade1 = t20_df_from2010.append(df_t2019)
print(t20_df_from2010.shape)
print(t20_decade1.shape)

t20_decade1.tail(2)
# Out:
# (590, 7)
# (704, 7)
#         Team1     Team2    Winner     Margin        Ground    Match_Date  \
# 112  Malaysia     Nepal     Nepal     6 runs  Kuala Lumpur  Jul 14, 2019
# 113   Ireland  Zimbabwe  Zimbabwe  8 wickets        Bready  Jul 14, 2019
#
#       Scorecard
# 112  T20I # 830
# 113  T20I # 831

# %% [markdown]
# ### Test 2019

# %%
data_list_test19 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2019;type=year', header = 0)
    
df_test19 = data_list_test19[0]
df_test19.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test19.shape)
df_test19.tail(2)
# Out:
# (13, 7)
#           Team1       Team2       Winner          Margin      Ground  \
# 11  New Zealand  Bangladesh  New Zealand  inns & 12 runs  Wellington
# 12  Afghanistan     Ireland  Afghanistan       7 wickets    Dehradun
#
#          Match_Date    Scorecard
# 11   Mar 8-12, 2019  Test # 2350
# 12  Mar 15-18, 2019  Test # 2351

# %%
test_decade1 = test_df_from2010.append(df_test19)
print(test_df_from2010.shape)
print(test_decade1.shape)

test_decade1.tail(2)
# Out:
# (395, 7)
# (408, 7)
#           Team1       Team2       Winner          Margin      Ground  \
# 11  New Zealand  Bangladesh  New Zealand  inns & 12 runs  Wellington
# 12  Afghanistan     Ireland  Afghanistan       7 wickets    Dehradun
#
#          Match_Date    Scorecard
# 11   Mar 8-12, 2019  Test # 2350
# 12  Mar 15-18, 2019  Test # 2351

# %% [markdown]
# # DECADE 2 <br>
#
# ## Cricket 2009 <br>
#
# ### ODI 2009

# %%
data_list_odi09 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2009;type=year', header = 0)
    
df_odi09 = data_list_odi09[0]
df_odi09.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi09.shape)
df_odi09.tail(2)
# Out:
# (150, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### T20 2009

# %%
data_list_t2009 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2009;type=year', header = 0)
    
df_t2009 = data_list_t2009[0]
df_t2009.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2009.shape)
df_t2009.tail(2)
# Out:
# (48, 7)
#     Team1      Team2     Winner     Margin  Ground    Match_Date   Scorecard
# 46  India  Sri Lanka  Sri Lanka    29 runs  Nagpur   Dec 9, 2009  T20I # 126
# 47  India  Sri Lanka      India  6 wickets  Mohali  Dec 12, 2009  T20I # 127

# %% [markdown]
# ### Test 2009

# %%
data_list_test09 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2009;type=year', header = 0)
    
df_test09 = data_list_test09[0]
df_test09.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test09.shape)
df_test09.head(2)
# Out:
# (41, 7)
#         Team1         Team2     Winner    Margin      Ground     Match_Date  \
# 0   Australia  South Africa  Australia  103 runs      Sydney  Jan 3-7, 2009
# 1  Bangladesh     Sri Lanka  Sri Lanka  465 runs  Chattogram  Jan 3-6, 2009
#
#      Scorecard
# 0  Test # 1904
# 1  Test # 1905

# %% [markdown]
# ## Cricket 2008 <br>
#
# ### ODI 2008

# %%
data_list_odi08 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2008;type=year', header = 0)
    
df_odi08 = data_list_odi08[0]
df_odi08.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi08.shape)
df_odi08.head(2)
# Out:
# (126, 7)
#           Team1        Team2        Winner     Margin     Ground  \
# 0  South Africa  West Indies  South Africa  6 wickets  Centurion
# 1      Pakistan     Zimbabwe      Pakistan   104 runs    Karachi
#
#      Match_Date   Scorecard
# 0  Jan 20, 2008  ODI # 2661
# 1  Jan 21, 2008  ODI # 2662

# %%
odi_df_from08 = df_odi08.append(df_odi09)
print(df_odi09.shape)
print(odi_df_from08.shape)

odi_df_from08.tail(2)
# Out:
# (150, 7)
# (276, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### T20 2008

# %%
data_list_t2008 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2008;type=year', header = 0)
    
df_t2008 = data_list_t2008[0]
df_t2008.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2008.shape)
df_t2008.head(2)
# Out:
# (29, 7)
#           Team1        Team2        Winner     Margin        Ground  \
# 0  South Africa  West Indies  South Africa  4 wickets  Johannesburg
# 1     Australia        India     Australia  9 wickets     Melbourne
#
#      Match_Date  Scorecard
# 0  Jan 18, 2008  T20I # 51
# 1   Feb 1, 2008  T20I # 52

# %%
t20_df_from08 = df_t2008.append(df_t2009)
print(df_t2009.shape)
print(t20_df_from08.shape)

t20_df_from08.tail(2)
# Out:
# (48, 7)
# (77, 7)
#     Team1      Team2     Winner     Margin  Ground    Match_Date   Scorecard
# 46  India  Sri Lanka  Sri Lanka    29 runs  Nagpur   Dec 9, 2009  T20I # 126
# 47  India  Sri Lanka      India  6 wickets  Mohali  Dec 12, 2009  T20I # 127

# %% [markdown]
# ### Test 2008

# %%
data_list_test08 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2008;type=year', header = 0)
    
df_test08 = data_list_test08[0]
df_test08.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test08.shape)
df_test08.head(2)
# Out:
# (47, 7)
#           Team1        Team2        Winner     Margin     Ground  \
# 0     Australia        India     Australia   122 runs     Sydney
# 1  South Africa  West Indies  South Africa  7 wickets  Cape Town
#
#       Match_Date    Scorecard
# 0  Jan 2-6, 2008  Test # 1857
# 1  Jan 2-5, 2008  Test # 1858

# %%
test_df_from08 = df_test08.append(df_test09)
print(df_test09.shape)
print(test_df_from08.shape)

test_df_from08.tail(2)
# Out:
# (41, 7)
# (88, 7)
#            Team1     Team2     Winner          Margin     Ground  \
# 39     Australia  Pakistan  Australia        170 runs  Melbourne
# 40  South Africa   England    England  inns & 98 runs     Durban
#
#          Match_Date    Scorecard
# 39  Dec 26-30, 2009  Test # 1943
# 40  Dec 26-30, 2009  Test # 1944

# %% [markdown]
# ## Cricket 2007 <br>
# appended
#
# ### ODI 2007

# %%
data_list_odi07 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2007;type=year', header = 0)
    
df_odi07 = data_list_odi07[0]
df_odi07.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi07.shape)
df_odi07.head(2)
# Out:
# (191, 7)
#          Team1      Team2       Winner     Margin        Ground   Match_Date  \
# 0  New Zealand  Sri Lanka  New Zealand  4 wickets  Christchurch  Jan 2, 2007
# 1  New Zealand  Sri Lanka    Sri Lanka   189 runs      Auckland  Jan 6, 2007
#
#     Scorecard
# 0  ODI # 2470
# 1  ODI # 2471

# %%
odi_df_from07 = df_odi07.append(odi_df_from08)
print(odi_df_from08.shape)
print(odi_df_from07.shape)

odi_df_from07.tail(2)
# Out:
# (276, 7)
# (467, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### T20 2007

# %%
data_list_t2007 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2007;type=year', header = 0)
    
df_t2007 = data_list_t2007[0]
df_t2007.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2007.shape)
df_t2007.head(2)
# Out:
# (38, 7)
#           Team1     Team2        Winner      Margin        Ground  \
# 0     Australia   England     Australia     77 runs        Sydney
# 1  South Africa  Pakistan  South Africa  10 wickets  Johannesburg
#
#     Match_Date  Scorecard
# 0  Jan 9, 2007  T20I # 13
# 1  Feb 2, 2007  T20I # 14

# %%
t20_df_from07 = df_t2007.append(t20_df_from08)
print(t20_df_from08.shape)
print(t20_df_from07.shape)

t20_df_from07.tail(2)
# Out:
# (77, 7)
# (115, 7)
#     Team1      Team2     Winner     Margin  Ground    Match_Date   Scorecard
# 46  India  Sri Lanka  Sri Lanka    29 runs  Nagpur   Dec 9, 2009  T20I # 126
# 47  India  Sri Lanka      India  6 wickets  Mohali  Dec 12, 2009  T20I # 127

# %% [markdown]
# ### Test 2007

# %%
data_list_test07 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2007;type=year', header = 0)
    
df_test07 = data_list_test07[0]
df_test07.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test07.shape)
df_test07.head(2)
# Out:
# (31, 7)
#           Team1    Team2        Winner      Margin     Ground     Match_Date  \
# 0     Australia  England     Australia  10 wickets     Sydney  Jan 2-5, 2007
# 1  South Africa    India  South Africa   5 wickets  Cape Town  Jan 2-6, 2007
#
#      Scorecard
# 0  Test # 1826
# 1  Test # 1827

# %%
test_df_from07 = df_test07.append(test_df_from08)
print(test_df_from08.shape)
print(test_df_from07.shape)

test_df_from07.head(2)
# Out:
# (88, 7)
# (119, 7)
#           Team1    Team2        Winner      Margin     Ground     Match_Date  \
# 0     Australia  England     Australia  10 wickets     Sydney  Jan 2-5, 2007
# 1  South Africa    India  South Africa   5 wickets  Cape Town  Jan 2-6, 2007
#
#      Scorecard
# 0  Test # 1826
# 1  Test # 1827

# %% [markdown]
# ## Cricket 2006 <br>
# appended
#
# ### ODI 2006

# %%
data_list_odi06 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2006;type=year', header = 0)
    
df_odi06 = data_list_odi06[0]
df_odi06.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi06.shape)
df_odi06.head(2)
# Out:
# (160, 7)
#          Team1      Team2       Winner     Margin        Ground   Match_Date  \
# 0  New Zealand  Sri Lanka  New Zealand  5 wickets  Christchurch  Jan 3, 2006
# 1  New Zealand  Sri Lanka  New Zealand    21 runs    Wellington  Jan 6, 2006
#
#     Scorecard
# 0  ODI # 2310
# 1  ODI # 2311

# %%
odi_df_from06 = df_odi06.append(odi_df_from07)
print(odi_df_from07.shape)
print(odi_df_from06.shape)

odi_df_from06.tail(2)
# Out:
# (467, 7)
# (627, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### T20 2006

# %%
data_list_t2006 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2006;type=year', header = 0)
    
df_t2006 = data_list_t2006[0]
df_t2006.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2006.shape)
df_t2006.head(2)
# Out:
# (9, 7)
#          Team1         Team2     Winner   Margin    Ground    Match_Date  \
# 0    Australia  South Africa  Australia  95 runs  Brisbane   Jan 9, 2006
# 1  New Zealand   West Indies       tied      NaN  Auckland  Feb 16, 2006
#
#   Scorecard
# 0  T20I # 4
# 1  T20I # 5

# %%
t20_df_from06 = df_t2006.append(t20_df_from07)
print(t20_df_from07.shape)
print(t20_df_from06.shape)

t20_df_from06.tail(2)
# Out:
# (115, 7)
# (124, 7)
#     Team1      Team2     Winner     Margin  Ground    Match_Date   Scorecard
# 46  India  Sri Lanka  Sri Lanka    29 runs  Nagpur   Dec 9, 2009  T20I # 126
# 47  India  Sri Lanka      India  6 wickets  Mohali  Dec 12, 2009  T20I # 127

# %% [markdown]
# ### Test 2006

# %%
data_list_test06 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2006;type=year', header = 0)
    
df_test06 = data_list_test06[0]
df_test06.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test06.shape)
df_test06.head(2)
# Out:
# (46, 7)
#        Team1         Team2     Winner     Margin  Ground       Match_Date  \
# 0  Australia  South Africa  Australia  8 wickets  Sydney    Jan 2-6, 2006
# 1   Pakistan         India      drawn        NaN  Lahore  Jan 13-17, 2006
#
#      Scorecard
# 0  Test # 1780
# 1  Test # 1781

# %%
test_df_from06 = df_test06.append(test_df_from07)
print(test_df_from07.shape)
print(test_df_from06.shape)

test_df_from06.head(2)
# Out:
# (119, 7)
# (165, 7)
#        Team1         Team2     Winner     Margin  Ground       Match_Date  \
# 0  Australia  South Africa  Australia  8 wickets  Sydney    Jan 2-6, 2006
# 1   Pakistan         India      drawn        NaN  Lahore  Jan 13-17, 2006
#
#      Scorecard
# 0  Test # 1780
# 1  Test # 1781

# %% [markdown]
# ## Cricket 2005 <br>
# appended
#
# ### ODI 2005

# %%
data_list_odi05 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2005;type=year', header = 0)
    
df_odi05 = data_list_odi05[0]
df_odi05.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi05.shape)
df_odi05.head(2)
# Out:
# (107, 7)
#        Team1         Team2        Winner    Margin     Ground    Match_Date  \
# 0    Asia XI  ICC World XI  ICC World XI  112 runs  Melbourne  Jan 10, 2005
# 1  Australia   West Indies     Australia  116 runs  Melbourne  Jan 14, 2005
#
#     Scorecard
# 0  ODI # 2203
# 1  ODI # 2204

# %%
odi_df_from05 = df_odi05.append(odi_df_from06)
print(odi_df_from06.shape)
print(odi_df_from05.shape)

odi_df_from05.head(2)
# Out:
# (627, 7)
# (734, 7)
#        Team1         Team2        Winner    Margin     Ground    Match_Date  \
# 0    Asia XI  ICC World XI  ICC World XI  112 runs  Melbourne  Jan 10, 2005
# 1  Australia   West Indies     Australia  116 runs  Melbourne  Jan 14, 2005
#
#     Scorecard
# 0  ODI # 2203
# 1  ODI # 2204

# %% [markdown]
# ### T20 2005

# %%
data_list_t2005 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id=2005;type=year', header = 0)
    
df_t2005 = data_list_t2005[0]
df_t2005.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_t2005.shape)
df_t2005.head(2)
# Out:
# (3, 7)
#          Team1      Team2     Winner    Margin       Ground    Match_Date  \
# 0  New Zealand  Australia  Australia   44 runs     Auckland  Feb 17, 2005
# 1      England  Australia    England  100 runs  Southampton  Jun 13, 2005
#
#   Scorecard
# 0  T20I # 1
# 1  T20I # 2

# %%
t20_df_from05 = df_t2005.append(t20_df_from06)
print(t20_df_from06.shape)
print(t20_df_from05.shape)

t20_df_from05.head()
# Out:
# (124, 7)
# (127, 7)
#           Team1         Team2       Winner     Margin        Ground  \
# 0   New Zealand     Australia    Australia    44 runs      Auckland
# 1       England     Australia      England   100 runs   Southampton
# 2  South Africa   New Zealand  New Zealand  5 wickets  Johannesburg
# 0     Australia  South Africa    Australia    95 runs      Brisbane
# 1   New Zealand   West Indies         tied        NaN      Auckland
#
#      Match_Date Scorecard
# 0  Feb 17, 2005  T20I # 1
# 1  Jun 13, 2005  T20I # 2
# 2  Oct 21, 2005  T20I # 3
# 0   Jan 9, 2006  T20I # 4
# 1  Feb 16, 2006  T20I # 5

# %% [markdown]
# ### Test 2005

# %%
data_list_test05 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2005;type=year', header = 0)
    
df_test05 = data_list_test05[0]
df_test05.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test05.shape)
df_test05.head(2)
# Out:
# (49, 7)
#           Team1     Team2        Winner     Margin     Ground     Match_Date  \
# 0     Australia  Pakistan     Australia  9 wickets     Sydney  Jan 2-5, 2005
# 1  South Africa   England  South Africa   196 runs  Cape Town  Jan 2-6, 2005
#
#      Scorecard
# 0  Test # 1731
# 1  Test # 1732

# %%
test_df_from05 = df_test05.append(test_df_from06)
print(test_df_from06.shape)
print(test_df_from05.shape)

test_df_from05.tail(2)
# Out:
# (165, 7)
# (214, 7)
#            Team1     Team2     Winner          Margin     Ground  \
# 39     Australia  Pakistan  Australia        170 runs  Melbourne
# 40  South Africa   England    England  inns & 98 runs     Durban
#
#          Match_Date    Scorecard
# 39  Dec 26-30, 2009  Test # 1943
# 40  Dec 26-30, 2009  Test # 1944

# %% [markdown]
# ## Cricket 2004 <br>
#
# #### No more T20 data <br>
#
# ### ODI 2004

# %%
data_list_odi04 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2004;type=year', header = 0)
    
df_odi04 = data_list_odi04[0]
df_odi04.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi04.shape)
df_odi04.head(2)
# Out:
# (128, 7)
#          Team1     Team2       Winner     Margin      Ground   Match_Date  \
# 0  New Zealand  Pakistan  New Zealand  4 wickets    Auckland  Jan 3, 2004
# 1  New Zealand  Pakistan     Pakistan  6 wickets  Queenstown  Jan 7, 2004
#
#     Scorecard
# 0  ODI # 2075
# 1  ODI # 2076

# %%
odi_df_from04 = df_odi04.append(odi_df_from05)
print(odi_df_from05.shape)
print(odi_df_from04.shape)

odi_df_from04.head(2)
# Out:
# (734, 7)
# (862, 7)
#          Team1     Team2       Winner     Margin      Ground   Match_Date  \
# 0  New Zealand  Pakistan  New Zealand  4 wickets    Auckland  Jan 3, 2004
# 1  New Zealand  Pakistan     Pakistan  6 wickets  Queenstown  Jan 7, 2004
#
#     Scorecard
# 0  ODI # 2075
# 1  ODI # 2076

# %% [markdown]
# ### Test 2004

# %%
data_list_test04 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2004;type=year', header = 0)
    
df_test04 = data_list_test04[0]
df_test04.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test04.shape)
df_test04.head(2)
# Out:
# (51, 7)
#           Team1        Team2 Winner Margin     Ground     Match_Date  \
# 0     Australia        India  drawn    NaN     Sydney  Jan 2-6, 2004
# 1  South Africa  West Indies  drawn    NaN  Cape Town  Jan 2-6, 2004
#
#      Scorecard
# 0  Test # 1680
# 1  Test # 1681

# %%
test_df_from04 = df_test04.append(test_df_from05)
print(test_df_from05.shape)
print(test_df_from04.shape)

test_df_from04.tail(2)
# Out:
# (214, 7)
# (265, 7)
#            Team1     Team2     Winner          Margin     Ground  \
# 39     Australia  Pakistan  Australia        170 runs  Melbourne
# 40  South Africa   England    England  inns & 98 runs     Durban
#
#          Match_Date    Scorecard
# 39  Dec 26-30, 2009  Test # 1943
# 40  Dec 26-30, 2009  Test # 1944

# %% [markdown]
# ## Cricket 2003 <br>
# appended
#
# ### ODI 2003

# %%
data_list_odi03 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2003;type=year', header = 0)
    
df_odi03 = data_list_odi03[0]
df_odi03.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi03.shape)
df_odi03.head(2)
# Out:
# (147, 7)
#          Team1  Team2       Winner     Margin        Ground   Match_Date  \
# 0  New Zealand  India  New Zealand  5 wickets  Christchurch  Jan 1, 2003
# 1  New Zealand  India  New Zealand  7 wickets    Queenstown  Jan 4, 2003
#
#     Scorecard
# 0  ODI # 1928
# 1  ODI # 1929

# %%
odi_df_from03 = df_odi03.append(odi_df_from04)
print(odi_df_from04.shape)
print(odi_df_from03.shape)

odi_df_from03.tail(2)
# Out:
# (862, 7)
# (1009, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### Test 2003

# %%
data_list_test03 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2003;type=year', header = 0)
    
df_test03 = data_list_test03[0]
df_test03.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test03.shape)
df_test03.head(2)
# Out:
# (44, 7)
#           Team1     Team2        Winner           Margin     Ground  \
# 0     Australia   England       England         225 runs     Sydney
# 1  South Africa  Pakistan  South Africa  inns & 142 runs  Cape Town
#
#       Match_Date    Scorecard
# 0  Jan 2-6, 2003  Test # 1636
# 1  Jan 2-5, 2003  Test # 1637

# %%
test_df_from03 = df_test03.append(test_df_from04)
print(test_df_from04.shape)
print(test_df_from03.shape)

test_df_from03.tail(2)
# Out:
# (265, 7)
# (309, 7)
#            Team1     Team2     Winner          Margin     Ground  \
# 39     Australia  Pakistan  Australia        170 runs  Melbourne
# 40  South Africa   England    England  inns & 98 runs     Durban
#
#          Match_Date    Scorecard
# 39  Dec 26-30, 2009  Test # 1943
# 40  Dec 26-30, 2009  Test # 1944

# %% [markdown]
# ## Cricket 2002 <br>
# appended
#
# ### ODI 2002

# %%
data_list_odi02 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2002;type=year', header = 0)
    
df_odi02 = data_list_odi02[0]
df_odi02.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi02.shape)
df_odi02.head(2)
# Out:
# (145, 7)
#        Team1         Team2        Winner     Margin     Ground    Match_Date  \
# 0  Australia   New Zealand   New Zealand    23 runs  Melbourne  Jan 11, 2002
# 1  Australia  South Africa  South Africa  4 wickets  Melbourne  Jan 13, 2002
#
#     Scorecard
# 0  ODI # 1783
# 1  ODI # 1784

# %%
odi_df_from02 = df_odi02.append(odi_df_from03)
print(odi_df_from03.shape)
print(odi_df_from02.shape)

odi_df_from02.head(2)
# Out:
# (1009, 7)
# (1154, 7)
#        Team1         Team2        Winner     Margin     Ground    Match_Date  \
# 0  Australia   New Zealand   New Zealand    23 runs  Melbourne  Jan 11, 2002
# 1  Australia  South Africa  South Africa  4 wickets  Melbourne  Jan 13, 2002
#
#     Scorecard
# 0  ODI # 1783
# 1  ODI # 1784

# %% [markdown]
# ### Test 2002

# %%
data_list_test02 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2002;type=year', header = 0)
    
df_test02 = data_list_test02[0]
df_test02.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test02.shape)
df_test02.head(2)
# Out:
# (54, 7)
#        Team1         Team2     Winner          Margin  Ground     Match_Date  \
# 0  Australia  South Africa  Australia      10 wickets  Sydney  Jan 2-5, 2002
# 1  Sri Lanka      Zimbabwe  Sri Lanka  inns & 94 runs   Kandy  Jan 4-7, 2002
#
#      Scorecard
# 0  Test # 1582
# 1  Test # 1583

# %%
test_df_from02 = df_test02.append(test_df_from03)
print(test_df_from03.shape)
print(test_df_from02.shape)

test_df_from02.head(2)
# Out:
# (309, 7)
# (363, 7)
#        Team1         Team2     Winner          Margin  Ground     Match_Date  \
# 0  Australia  South Africa  Australia      10 wickets  Sydney  Jan 2-5, 2002
# 1  Sri Lanka      Zimbabwe  Sri Lanka  inns & 94 runs   Kandy  Jan 4-7, 2002
#
#      Scorecard
# 0  Test # 1582
# 1  Test # 1583

# %% [markdown]
# ## Cricket 2001 <br>
#
# appended
#
# ### ODI 2001

# %%
data_list_odi01 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2001;type=year', header = 0)
    
df_odi01 = data_list_odi01[0]
df_odi01.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi01.shape)
df_odi01.head(2)
# Out:
# (120, 7)
#          Team1     Team2       Winner     Margin      Ground   Match_Date  \
# 0  New Zealand  Zimbabwe     Zimbabwe    70 runs       Taupo  Jan 2, 2001
# 1  New Zealand  Zimbabwe  New Zealand  8 wickets  Wellington  Jan 4, 2001
#
#     Scorecard
# 0  ODI # 1663
# 1  ODI # 1664

# %%
odi_df_from01 = df_odi01.append(odi_df_from02)
print(odi_df_from02.shape)
print(odi_df_from01.shape)

odi_df_from01.tail(2)
# Out:
# (1154, 7)
# (1274, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### Test 2001

# %%
data_list_test01 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2001;type=year', header = 0)
    
df_test01 = data_list_test01[0]
df_test01.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test01.shape)
df_test01.head(2)
# Out:
# (55, 7)
#           Team1        Team2        Winner           Margin     Ground  \
# 0     Australia  West Indies     Australia        6 wickets     Sydney
# 1  South Africa    Sri Lanka  South Africa  inns & 229 runs  Cape Town
#
#       Match_Date    Scorecard
# 0  Jan 2-6, 2001  Test # 1527
# 1  Jan 2-4, 2001  Test # 1528

# %%
test_df_from01 = df_test01.append(test_df_from02)
print(test_df_from02.shape)
print(test_df_from01.shape)

test_df_from01.tail(2)
# Out:
# (363, 7)
# (418, 7)
#            Team1     Team2     Winner          Margin     Ground  \
# 39     Australia  Pakistan  Australia        170 runs  Melbourne
# 40  South Africa   England    England  inns & 98 runs     Durban
#
#          Match_Date    Scorecard
# 39  Dec 26-30, 2009  Test # 1943
# 40  Dec 26-30, 2009  Test # 1944

# %% [markdown]
# ## Cricket 2000 <br>
# appended all of decade 2 data
#
# ### ODI 2000

# %%
data_list_odi2000 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id=2000;type=year', header = 0)
    
df_odi00 = data_list_odi2000[0]
df_odi00.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_odi00.shape)
df_odi00.head(2)
# Out:
# (131, 7)
#          Team1        Team2       Winner     Margin    Ground   Match_Date  \
# 0  New Zealand  West Indies  New Zealand  3 wickets  Auckland  Jan 2, 2000
# 1  New Zealand  West Indies  New Zealand  7 wickets     Taupo  Jan 4, 2000
#
#     Scorecard
# 0  ODI # 1532
# 1  ODI # 1533

# %%
odi_decade2 = df_odi00.append(odi_df_from01)
print(odi_df_from01.shape)
print(odi_decade2.shape)

odi_decade2.tail(2)
# Out:
# (1274, 7)
# (1405, 7)
#      Team1      Team2     Winner     Margin   Ground    Match_Date   Scorecard
# 148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009  ODI # 2935
# 149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009  ODI # 2936

# %% [markdown]
# ### Test 2000

# %%
data_list_test2000 = pd.read_html('http://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id=2000;type=year', header = 0)
    
df_test00 = data_list_test2000[0]
df_test00.columns = ['Team1', 'Team2', 'Winner', 'Margin', 
              'Ground', 'Match_Date', 'Scorecard']

print(df_test00.shape)
df_test00.head(2)
# Out:
# (46, 7)
#           Team1    Team2        Winner           Margin     Ground  \
# 0     Australia    India     Australia  inns & 141 runs     Sydney
# 1  South Africa  England  South Africa   inns & 37 runs  Cape Town
#
#       Match_Date    Scorecard
# 0  Jan 2-4, 2000  Test # 1481
# 1  Jan 2-5, 2000  Test # 1482

# %%
test_decade2 = df_test00.append(test_df_from01)
print(test_df_from01.shape)
print(test_decade2.shape)

test_decade2.tail(2)
# Out:
# (418, 7)
# (464, 7)
#            Team1     Team2     Winner          Margin     Ground  \
# 39     Australia  Pakistan  Australia        170 runs  Melbourne
# 40  South Africa   England    England  inns & 98 runs     Durban
#
#          Match_Date    Scorecard
# 39  Dec 26-30, 2009  Test # 1943
# 40  Dec 26-30, 2009  Test # 1944

# %% [markdown]
# ## Read data into cvs <br>
#
# 1- odi for decade 1 <br>
# 2- t20 for decade 1 <br>
# 3- test for decade 1 <br>
# 4- odi for decade 2 <br>
# 5- t20 for decade 2 (only 5 years) <br>
# 6- test for decade 2 <br>
# 7 - combine both decades odi <br>
# 8- combine both decades t20 <br>
# 9- combine both deacdes test <br>

# %%
odi_decade1 = odi_decade1.reset_index()
odi_decade1.tail(2)
# Out:
#       level_0  index    Team1        Team2   Winner     Margin      Ground  \
# 1254     1254    117  England    Australia  England  8 wickets  Birmingham
# 1255     1255    118  England  New Zealand     tied        NaN      Lord's
#
#         Match_Date   Scorecard
# 1254  Jul 11, 2019  ODI # 4191
# 1255  Jul 14, 2019  ODI # 4192

# %%
odi_decade2 = odi_decade2.reset_index()
odi_decade2.tail(2)
# Out:
#       index  Team1      Team2     Winner     Margin   Ground    Match_Date  \
# 1403    148  India  Sri Lanka      India  7 wickets  Kolkata  Dec 24, 2009
# 1404    149  India  Sri Lanka  no result        NaN    Delhi  Dec 27, 2009
#
#        Scorecard
# 1403  ODI # 2935
# 1404  ODI # 2936

# %%
odi_decade1.to_csv("odi_decade1.csv")

# %%
odi_decade2.to_csv("odi_decade2.csv")

# %%
odi_combined = odi_decade2.append(odi_decade1, ignore_index=True, sort = False)
odi_combined.tail()
# Out:
#       index      Team1         Team2        Winner     Margin      Ground  \
# 2656    114  Australia  South Africa  South Africa    10 runs  Manchester
# 2657    115    Ireland      Zimbabwe       Ireland  6 wickets     Belfast
# 2658    116      India   New Zealand   New Zealand    18 runs  Manchester
# 2659    117    England     Australia       England  8 wickets  Birmingham
# 2660    118    England   New Zealand          tied        NaN      Lord's
#
#           Match_Date   Scorecard  level_0
# 2656     Jul 6, 2019  ODI # 4188   1251.0
# 2657     Jul 7, 2019  ODI # 4189   1252.0
# 2658  Jul 9-10, 2019  ODI # 4190   1253.0
# 2659    Jul 11, 2019  ODI # 4191   1254.0
# 2660    Jul 14, 2019  ODI # 4192   1255.0

# %%
odi_combined.to_csv("odi.csv")

# %%
t20_decade1 = t20_decade1.reset_index()
t20_decade1.tail()
# Out:
#      level_0  index     Team1     Team2    Winner     Margin        Ground  \
# 699      699    109  Malaysia     Nepal     Nepal  7 wickets  Kuala Lumpur
# 700      700    110   Denmark   Finland   Denmark      1 run       Brondby
# 701      701    111   Denmark   Finland   Denmark    38 runs       Brondby
# 702      702    112  Malaysia     Nepal     Nepal     6 runs  Kuala Lumpur
# 703      703    113   Ireland  Zimbabwe  Zimbabwe  8 wickets        Bready
#
#        Match_Date   Scorecard
# 699  Jul 13, 2019  T20I # 827
# 700  Jul 13, 2019  T20I # 828
# 701  Jul 13, 2019  T20I # 829
# 702  Jul 14, 2019  T20I # 830
# 703  Jul 14, 2019  T20I # 831

# %%
t20_decade1.to_csv("T20_decade1.csv")

# %%
t20_decade2 = t20_df_from05.reset_index()
t20_decade2.tail()
# Out:
#      index         Team1      Team2        Winner     Margin        Ground  \
# 122     43   New Zealand   Pakistan      Pakistan     7 runs   Dubai (DSC)
# 123     44  South Africa    England       England      1 run  Johannesburg
# 124     45  South Africa    England  South Africa    84 runs     Centurion
# 125     46         India  Sri Lanka     Sri Lanka    29 runs        Nagpur
# 126     47         India  Sri Lanka         India  6 wickets        Mohali
#
#        Match_Date   Scorecard
# 122  Nov 13, 2009  T20I # 123
# 123  Nov 13, 2009  T20I # 124
# 124  Nov 15, 2009  T20I # 125
# 125   Dec 9, 2009  T20I # 126
# 126  Dec 12, 2009  T20I # 127

# %%
t20_decade2.to_csv("T20_decade2.csv")

# %%
t20_combined = t20_decade2.append(t20_decade1, ignore_index = True, sort = False)
t20_combined.tail()
# Out:
#      index     Team1     Team2    Winner     Margin        Ground  \
# 826    109  Malaysia     Nepal     Nepal  7 wickets  Kuala Lumpur
# 827    110   Denmark   Finland   Denmark      1 run       Brondby
# 828    111   Denmark   Finland   Denmark    38 runs       Brondby
# 829    112  Malaysia     Nepal     Nepal     6 runs  Kuala Lumpur
# 830    113   Ireland  Zimbabwe  Zimbabwe  8 wickets        Bready
#
#        Match_Date   Scorecard  level_0
# 826  Jul 13, 2019  T20I # 827    699.0
# 827  Jul 13, 2019  T20I # 828    700.0
# 828  Jul 13, 2019  T20I # 829    701.0
# 829  Jul 14, 2019  T20I # 830    702.0
# 830  Jul 14, 2019  T20I # 831    703.0

# %%
t20_combined.to_csv("T20.csv")

# %%
test_decade1 = test_decade1.reset_index()
test_decade1.tail()
# Out:
#      level_0  index         Team1       Team2       Winner          Margin  \
# 403      403      8  South Africa   Sri Lanka    Sri Lanka        1 wicket
# 404      404      9  South Africa   Sri Lanka    Sri Lanka       8 wickets
# 405      405     10   New Zealand  Bangladesh  New Zealand  inns & 52 runs
# 406      406     11   New Zealand  Bangladesh  New Zealand  inns & 12 runs
# 407      407     12   Afghanistan     Ireland  Afghanistan       7 wickets
#
#              Ground          Match_Date    Scorecard
# 403          Durban     Feb 13-16, 2019  Test # 2347
# 404  Port Elizabeth     Feb 21-23, 2019  Test # 2348
# 405        Hamilton  Feb 28-Mar 3, 2019  Test # 2349
# 406      Wellington      Mar 8-12, 2019  Test # 2350
# 407        Dehradun     Mar 15-18, 2019  Test # 2351

# %%
test_decade1.to_csv("test_decade1.csv")

# %%
test_decade2 = test_decade2.reset_index()
test_decade2.tail()
# Out:
#      level_0  index         Team1        Team2     Winner          Margin  \
# 459      459     36   New Zealand     Pakistan      drawn             NaN
# 460      460     37     Australia  West Indies  Australia         35 runs
# 461      461     38  South Africa      England      drawn             NaN
# 462      462     39     Australia     Pakistan  Australia        170 runs
# 463      463     40  South Africa      England    England  inns & 98 runs
#
#         Ground       Match_Date    Scorecard
# 459     Napier  Dec 11-15, 2009  Test # 1940
# 460      Perth  Dec 16-20, 2009  Test # 1941
# 461  Centurion  Dec 16-20, 2009  Test # 1942
# 462  Melbourne  Dec 26-30, 2009  Test # 1943
# 463     Durban  Dec 26-30, 2009  Test # 1944

# %%
test_decade2.to_csv("test_decade2.csv")

# %%
test_combined = test_decade2.append(test_decade1, sort = False, ignore_index = True)
test_combined.tail()
# Out:
#      level_0  index         Team1       Team2       Winner          Margin  \
# 867      403      8  South Africa   Sri Lanka    Sri Lanka        1 wicket
# 868      404      9  South Africa   Sri Lanka    Sri Lanka       8 wickets
# 869      405     10   New Zealand  Bangladesh  New Zealand  inns & 52 runs
# 870      406     11   New Zealand  Bangladesh  New Zealand  inns & 12 runs
# 871      407     12   Afghanistan     Ireland  Afghanistan       7 wickets
#
#              Ground          Match_Date    Scorecard
# 867          Durban     Feb 13-16, 2019  Test # 2347
# 868  Port Elizabeth     Feb 21-23, 2019  Test # 2348
# 869        Hamilton  Feb 28-Mar 3, 2019  Test # 2349
# 870      Wellington      Mar 8-12, 2019  Test # 2350
# 871        Dehradun     Mar 15-18, 2019  Test # 2351

# %%
test_combined.to_csv("Test.csv")

# %% [markdown]
# ### Combining all cricket data

# %%
combo1 = odi_combined.append(test_combined, sort=False, ignore_index=True)
combo1.tail()
# Out:
#       index         Team1       Team2       Winner          Margin  \
# 3528      8  South Africa   Sri Lanka    Sri Lanka        1 wicket
# 3529      9  South Africa   Sri Lanka    Sri Lanka       8 wickets
# 3530     10   New Zealand  Bangladesh  New Zealand  inns & 52 runs
# 3531     11   New Zealand  Bangladesh  New Zealand  inns & 12 runs
# 3532     12   Afghanistan     Ireland  Afghanistan       7 wickets
#
#               Ground          Match_Date    Scorecard  level_0
# 3528          Durban     Feb 13-16, 2019  Test # 2347    403.0
# 3529  Port Elizabeth     Feb 21-23, 2019  Test # 2348    404.0
# 3530        Hamilton  Feb 28-Mar 3, 2019  Test # 2349    405.0
# 3531      Wellington      Mar 8-12, 2019  Test # 2350    406.0
# 3532        Dehradun     Mar 15-18, 2019  Test # 2351    407.0

# %%
cricket_df = combo1.append(t20_combined, sort=False, ignore_index=True)
cricket_df.tail()
# Out:
#       index     Team1     Team2    Winner     Margin        Ground  \
# 4359    109  Malaysia     Nepal     Nepal  7 wickets  Kuala Lumpur
# 4360    110   Denmark   Finland   Denmark      1 run       Brondby
# 4361    111   Denmark   Finland   Denmark    38 runs       Brondby
# 4362    112  Malaysia     Nepal     Nepal     6 runs  Kuala Lumpur
# 4363    113   Ireland  Zimbabwe  Zimbabwe  8 wickets        Bready
#
#         Match_Date   Scorecard  level_0
# 4359  Jul 13, 2019  T20I # 827    699.0
# 4360  Jul 13, 2019  T20I # 828    700.0
# 4361  Jul 13, 2019  T20I # 829    701.0
# 4362  Jul 14, 2019  T20I # 830    702.0
# 4363  Jul 14, 2019  T20I # 831    703.0

# %%
cricket_df.shape
# Out:
# (4364, 9)

# %%
cricket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4364 entries, 0 to 4363
# Data columns (total 9 columns):
# index         4364 non-null int64
# Team1         4364 non-null object
# Team2         4364 non-null object
# Winner        4364 non-null object
# Margin        4008 non-null object
# Ground        4364 non-null object
# Match_Date    4364 non-null object
# Scorecard     4364 non-null object
# level_0       2832 non-null float64
# dtypes: float64(1), int64(1), object(7)
# memory usage: 306.9+ KB

# %%
cricket_df.describe()
# Out:
#              index      level_0
# count  4364.000000  2832.000000
# mean     52.580431   432.923729
# std      39.899728   325.907000
# min       0.000000     0.000000
# 25%      20.000000   176.750000
# 50%      42.000000   353.500000
# 75%      81.000000   625.250000
# max     190.000000  1255.000000

# %%
cricket_df.to_csv("cricket.csv")
